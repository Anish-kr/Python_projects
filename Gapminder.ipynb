# %% [markdown]
# # Gapminder Data

# %% [markdown]
# In this Analysis I am going to use data from a different dataset 'Gapminder Data' -
# The data was obtained from the site [gapminder.org](http://www.gapminder.org/data/). The variables included are:
#
# * Aged 15+ Employment Rate (%)
# * Life Expectancy (years)
# * GDP/capita (US$, inflation adjusted)
# * Primary school completion (% of boys)
# * Primary school completion (% of girls)

# %%
## importing all the important libraries

import unicodecsv
import seaborn as sns
# %pylab inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# This was how we read csv file normally 
#def read_csv(filename):
#   with open(filename, 'rb') as f:
#        reader= unicodecsv.DictReader(f)
#        return list(reader)
#    

# But in this project we are going to do the same using pandas


employment_rate = pd.read_csv("employment_above_15.csv",index_col= 0)
life_expectancy = pd.read_csv("life_expectancy.csv",index_col= 0)
gdp_per_capita  = pd.read_csv("gdp_per_capita.csv",index_col= 0)
male_school_completion_rate = pd.read_csv("male_completion_rate.csv",index_col= 0)
female_school_completion_rate = pd.read_csv("female_completion_rate.csv",index_col= 0)

# %%
employment_rate.head()
# Out:
#                   1991       1992       1993       1994       1995       1996  \
# Country
# Afghanistan  56.700001  56.500000  56.599998  56.200001  56.200001  56.099998
# Albania      52.700001  52.299999  52.400002  52.700001  52.799999  52.599998
# Algeria      39.400002  38.900002  39.400002  39.400002  38.099998  38.900002
# Angola       75.800003  75.800003  75.500000  75.900002  75.800003  75.900002
# Argentina    53.599998  53.799999  53.700001  53.799999  53.500000  54.400002
#
#                   1997       1998       1999       2000       2001       2002  \
# Country
# Afghanistan  56.200001  56.200001  56.099998  56.099998  56.500000  56.400002
# Albania      52.400002  52.099998  52.099998  51.900002  51.799999  51.799999
# Algeria      39.700001  39.500000  39.400002  38.599998  40.400002  41.500000
# Angola       75.699997  75.599998  75.599998  75.500000  75.500000  75.599998
# Argentina    54.900002  55.000000  54.900002  55.500000  55.599998  55.400002
#
#                   2003       2004       2005       2006       2007
# Country
# Afghanistan  54.400002  56.000000  54.000000  56.000000  55.700001
# Albania      51.799999  51.700001  51.500000  51.400002  51.400002
# Algeria      42.799999  46.400002  48.000000  50.000000  50.500000
# Angola       75.500000  75.500000  75.599998  75.500000  75.699997
# Argentina    57.299999  57.700001  58.099998  58.400002  58.400002

# %%
life_expectancy.head()
# Out:
#                    1800       1801       1802      1803       1804       1805  \
# Country
# Afghanistan     28.2110  28.200753  28.190507  28.18026  28.170013  28.159767
# Albania         35.4000  35.400000  35.400000  35.40000  35.400000  35.400000
# Algeria         28.8224  28.822400  28.822400  28.82240  28.822400  28.822400
# American Samoa      NaN        NaN        NaN       NaN        NaN        NaN
# Andorra             NaN        NaN        NaN       NaN        NaN        NaN
#
#                     1806       1807       1808      1809  ...   2004  2005  \
# Country                                                   ...
# Afghanistan     28.14952  28.139273  28.129027  28.11878  ...   52.5  52.9
# Albania         35.40000  35.400000  35.400000  35.40000  ...   74.4  74.4
# Algeria         28.82240  28.822400  28.822400  28.82240  ...   74.2  74.5
# American Samoa       NaN        NaN        NaN       NaN  ...    NaN   NaN
# Andorra              NaN        NaN        NaN       NaN  ...   83.0  83.1
#
#                 2006  2007  2008  2009  2010  2011  2012  2013
# Country
# Afghanistan     53.2  53.6  54.0  54.5  54.8  55.2  55.5  56.2
# Albania         74.5  74.7  74.9  75.0  75.2  75.5  75.7  75.8
# Algeria         74.8  75.0  75.3  75.6  75.9  76.1  76.2  76.3
# American Samoa   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Andorra         83.2  83.4  83.5  83.6  83.7  83.8  83.8  83.9
#
# [5 rows x 205 columns]

# %%
gdp_per_capita.head()
# Out:
#                               1960         1961        1962        1963  \
# Country
# Abkhazia                       NaN          NaN         NaN         NaN
# Afghanistan                    NaN          NaN         NaN         NaN
# Akrotiri and Dhekelia          NaN          NaN         NaN         NaN
# Albania                        NaN          NaN         NaN         NaN
# Algeria                1280.384828  1085.414612  855.947986  1128.41578
#
#                               1964         1965         1966         1967  \
# Country
# Abkhazia                       NaN          NaN          NaN          NaN
# Afghanistan                    NaN          NaN          NaN          NaN
# Akrotiri and Dhekelia          NaN          NaN          NaN          NaN
# Albania                        NaN          NaN          NaN          NaN
# Algeria                1170.323896  1215.015783  1127.614288  1200.558225
#
#                               1968         1969     ...              2002  \
# Country                                             ...
# Abkhazia                       NaN          NaN     ...               NaN
# Afghanistan                    NaN          NaN     ...               NaN
# Akrotiri and Dhekelia          NaN          NaN     ...               NaN
# Albania                        NaN          NaN     ...       1313.722725
# Algeria                1291.863983  1359.491003     ...       1871.921986
#
#                               2003         2004         2005         2006  \
# Country
# Abkhazia                       NaN          NaN          NaN          NaN
# Afghanistan                    NaN          NaN          NaN          NaN
# Akrotiri and Dhekelia          NaN          NaN          NaN          NaN
# Albania                1381.040832  1454.022854  1525.723589  1594.495067
# Algeria                1971.512803  2043.135713  2115.186028  2124.957754
#
#                               2007         2008         2009         2010  \
# Country
# Abkhazia                       NaN          NaN          NaN          NaN
# Afghanistan                    NaN          NaN          NaN          NaN
# Akrotiri and Dhekelia          NaN          NaN          NaN          NaN
# Albania                1681.613910  1804.419415  1857.352947  1915.424459
# Algeria                2155.485231  2173.787903  2192.703976  2231.980246
#
#                               2011
# Country
# Abkhazia                       NaN
# Afghanistan                    NaN
# Akrotiri and Dhekelia          NaN
# Albania                1965.707230
# Algeria                2255.225482
#
# [5 rows x 52 columns]

# %%
male_school_completion_rate .head()
# Out:
#                        1970  1971     1972      1973      1974      1975  \
# Country
# Abkhazia                NaN   NaN      NaN       NaN       NaN       NaN
# Afghanistan             NaN   NaN      NaN       NaN  26.23178       NaN
# Akrotiri and Dhekelia   NaN   NaN      NaN       NaN       NaN       NaN
# Albania                 NaN   NaN      NaN       NaN       NaN       NaN
# Algeria                 NaN   NaN  55.3917  57.41252  60.71733  66.29215
#
#                            1976      1977      1978      1979    ...     \
# Country                                                          ...
# Abkhazia                    NaN       NaN       NaN       NaN    ...
# Afghanistan                 NaN  26.73849  29.07336       NaN    ...
# Akrotiri and Dhekelia       NaN       NaN       NaN       NaN    ...
# Albania                     NaN       NaN       NaN       NaN    ...
# Algeria                72.58079  75.04380  77.39284  76.08493    ...
#
#                            2002       2003      2004      2005  2006  \
# Country
# Abkhazia                    NaN        NaN       NaN       NaN   NaN
# Afghanistan                 NaN        NaN       NaN  48.36070   NaN
# Akrotiri and Dhekelia       NaN        NaN       NaN       NaN   NaN
# Albania                     NaN  101.90853  99.10666       NaN   NaN
# Algeria                90.34439   92.04006  92.68131  94.66572   NaN
#
#                            2007       2008      2009      2010      2011
# Country
# Abkhazia                    NaN        NaN       NaN       NaN       NaN
# Afghanistan                 NaN        NaN       NaN       NaN       NaN
# Akrotiri and Dhekelia       NaN        NaN       NaN       NaN       NaN
# Albania                     NaN   89.44897  88.83622  86.49044  88.18113
# Algeria                95.47622  121.33472  93.16440  96.09082  94.51607
#
# [5 rows x 42 columns]

# %%
female_school_completion_rate.head()
# Out:
#                        1970  1971      1972      1973      1974     1975  \
# Country
# Abkhazia                NaN   NaN       NaN       NaN       NaN      NaN
# Afghanistan             NaN   NaN       NaN       NaN   4.19285      NaN
# Akrotiri and Dhekelia   NaN   NaN       NaN       NaN       NaN      NaN
# Albania                 NaN   NaN       NaN       NaN       NaN      NaN
# Algeria                 NaN   NaN  30.90031  33.02938  34.32702  39.7942
#
#                            1976      1977      1978      1979    ...     \
# Country                                                          ...
# Abkhazia                    NaN       NaN       NaN       NaN    ...
# Afghanistan                 NaN   5.14529   5.91965       NaN    ...
# Akrotiri and Dhekelia       NaN       NaN       NaN       NaN    ...
# Albania                     NaN       NaN       NaN       NaN    ...
# Algeria                45.24156  48.22515  50.49138  51.07383    ...
#
#                            2002       2003      2004      2005  2006  \
# Country
# Abkhazia                    NaN        NaN       NaN       NaN   NaN
# Afghanistan                 NaN        NaN       NaN  18.74188   NaN
# Akrotiri and Dhekelia       NaN        NaN       NaN       NaN   NaN
# Albania                     NaN  100.27718  97.70814       NaN   NaN
# Algeria                90.09179   91.27633  93.30839  94.21432   NaN
#
#                            2007       2008      2009      2010      2011
# Country
# Abkhazia                    NaN        NaN       NaN       NaN       NaN
# Afghanistan                 NaN        NaN       NaN       NaN       NaN
# Akrotiri and Dhekelia       NaN        NaN       NaN       NaN       NaN
# Albania                     NaN   90.41091  89.76010  86.01452  89.53901
# Algeria                97.35583  109.72854  95.13346  95.87439  94.20928
#
# [5 rows x 42 columns]

# %%
female_school_completion_rate.loc['United States'].values
# Out:
# array([       nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,  103.01365,  102.05438,
#          98.64533,  101.04295,  102.61931,  103.75253,  100.26424,
#          96.14198,   99.09253,  101.44458,  102.04852,   99.53498,
#         103.99037,        nan])

# %% [markdown]
# ### Questions that we ask here are-
#
# 1) How has employment in U.S. And India varied over time?
#
# 2) Which are the highest and lowest employment levels?
#   * Which country have them?
#   * Where is U.S. on the spectrum?
#
# 3) Are there any constant trend among countries?

# %% [markdown]
# ### How the employment of countries varied over time?

# %%
def correlation(x,y):
    std_x = (x-x.mean())/(x.std(ddof = 0))
    std_y = (y-y.mean())/(y.std(ddof=0))
    
    return (std_x * std_y).mean()
def emp_country(country,df):
    emp_country=df.loc[country]
    year_are=df.columns.values.astype(str).astype(int)
    return correlation(emp_country.values, year_are)

# %%
emp_country('India',employment_rate)
# Out:
# -0.9519721316199079

# %%
emp_country('United States',employment_rate)
# Out:
# 0.21615801555032632

# %%
year_for_country=employment_rate.columns.values.astype(str).astype(int)
emp_US=employment_rate.loc['United States']

def scatter_plot(df,country,clr, mrkr):
    yr_for_total = df.columns.values.astype(str).astype(int)
    emp_country_wise= df.loc[country]
    plt.scatter(yr_for_total,emp_country_wise,
    #color
    color=clr,
    #marker
    marker=mrkr)
    # Chart title
    plt.title('Varition of Employment rate with time')
    # y label
    plt.ylabel('Employment Rate')
    # x label
    plt.xlabel('Year')
    # and a legend
    plt.legend(loc='upper right')
    
    
    
    

scatter_plot(employment_rate, 'India','red','^')

# %%
scatter_plot(employment_rate, 'United States','black','o')

# %% [markdown]
# **Thus it appears like employment for U.S. increased from the year 1992 to 2000. And then it again it started to decrease until 2003 when due to some reason it again started increasing.**

# %%
def finding_corr(df):
    corr_list=[]
    for country in df.index.values.astype('str'):
        corr_list.append(emp_country(country,df))
    return pd.DataFrame(data = corr_list, index= df.index.values.astype('str'))
    

finding_corr(employment_rate)
# Out:
#                                0
# Afghanistan            -0.580820
# Albania                -0.925576
# Algeria                 0.830397
# Angola                 -0.583829
# Argentina               0.951878
# Armenia                 0.643514
# Australia               0.957519
# Austria                 0.728565
# Azerbaijan              0.838253
# Bahamas                 0.706054
# Bahrain                -0.620271
# Bangladesh             -0.912804
# Barbados                0.904470
# Belarus                -0.842370
# Belgium                 0.871702
# Belize                  0.950069
# Benin                  -0.211379
# Bhutan                  0.738709
# Bolivia                 0.914417
# Bosnia and Herzegovina -0.958272
# Botswana               -0.476137
# Brazil                  0.902292
# Brunei                  0.791400
# Bulgaria               -0.137561
# Burkina Faso            0.945403
# Burundi                -0.763042
# Cambodia                0.500457
# Cameroon                0.364258
# Canada                  0.929463
# Cape Verde             -0.863962
# ...                          ...
# Sri Lanka               0.772248
# Sudan                   0.653708
# Suriname                0.349557
# Swaziland              -0.871388
# Sweden                  0.034572
# Switzerland            -0.771132
# Syria                  -0.414254
# Taiwan                 -0.859848
# Tajikistan              0.159174
# Tanzania               -0.936702
# Thailand               -0.799763
# Macedonia, FYR         -0.645464
# Togo                   -0.941933
# Trinidad and Tobago     0.987931
# Tunisia                 0.737584
# Turkey                 -0.940649
# Turkmenistan            0.728569
# Uganda                 -0.730804
# Ukraine                -0.686243
# United Arab Emirates    0.949513
# United Kingdom          0.865302
# United States           0.216158
# Uruguay                 0.912847
# Uzbekistan              0.837195
# Venezuela               0.792558
# Vietnam                -0.958890
# West Bank and Gaza      0.169005
# Yemen, Rep.             0.227651
# Zambia                  0.841578
# Zimbabwe               -0.918114
#
# [178 rows x 1 columns]

# %% [markdown]
# ### Which are the highest and lowest employment levels?

# %%
##Year_wise max-values are as follows
employment_rate.apply(argmax).values.astype(str)
# Out:
# array(['Tanzania', 'Tanzania', 'Rwanda', 'Rwanda', 'Rwanda', 'Rwanda',
#        'Rwanda', 'Tanzania', 'Tanzania', 'Tanzania', 'Burundi', 'Burundi',
#        'Burundi', 'Burundi', 'Madagascar', 'Madagascar', 'Burundi'],
#       dtype='|S10')

# %%
employment_level_variation=pd.DataFrame({ 'Max Employment Each Year':employment_rate.max(),
    'Respective Countries' :employment_rate.apply(argmax)})
employment_level_variation
# Out:
#       Max Employment Each Year Respective Countries
# 1991                 87.500000             Tanzania
# 1992                 87.199997             Tanzania
# 1993                 87.000000               Rwanda
# 1994                 87.699997               Rwanda
# 1995                 87.300003               Rwanda
# 1996                 86.800003               Rwanda
# 1997                 86.099998               Rwanda
# 1998                 85.900002             Tanzania
# 1999                 85.699997             Tanzania
# 2000                 85.099998             Tanzania
# 2001                 84.300003              Burundi
# 2002                 84.000000              Burundi
# 2003                 83.599998              Burundi
# 2004                 83.400002              Burundi
# 2005                 84.300003           Madagascar
# 2006                 84.099998           Madagascar
# 2007                 83.199997              Burundi

# %% [markdown]
# #### Which is the highest employment level throughout? Which country has it?
#
#      FOr this let us sort the above dataframe in descending order.

# %%
sorted_employ=employment_level_variation.sort_values(by='Max Employment Each Year' , axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last')

sorted_employ
# Out:
#       Max Employment Each Year Respective Countries
# 1994                 87.699997               Rwanda
# 1991                 87.500000             Tanzania
# 1995                 87.300003               Rwanda
# 1992                 87.199997             Tanzania
# 1993                 87.000000               Rwanda
# 1996                 86.800003               Rwanda
# 1997                 86.099998               Rwanda
# 1998                 85.900002             Tanzania
# 1999                 85.699997             Tanzania
# 2000                 85.099998             Tanzania
# 2001                 84.300003              Burundi
# 2005                 84.300003           Madagascar
# 2006                 84.099998           Madagascar
# 2002                 84.000000              Burundi
# 2003                 83.599998              Burundi
# 2004                 83.400002              Burundi
# 2007                 83.199997              Burundi

# %%
print "The highest employment level throughout is",employment_rate.values.max(),"and this was for",sorted_employ['Respective Countries'][0]
# Out:
# The highest employment level throughout is 87.6999969482 and this was for Rwanda
